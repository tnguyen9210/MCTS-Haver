# %%
from collections import defaultdict
import random
import numpy as np
np.set_printoptions(precision=2, suppress=True)

import time
import copy 
import multiprocess as mp

import gym
from env import FrozenLakeCustom, FrozenLakeSimulator

from mcts_haver import run_mcts_trial
from value_iteration import value_iteration

from config import parse_args
from utils import MultiProcess

import logging
logger = logging.getLogger()
logger.setLevel(logging.FATAL)

# %%
np.random.seed(0)
random.seed(0)

# params
args = parse_args()

#
env_id = "FrozenLake-v1"
env = FrozenLakeCustom(
    map_name=args["map_name"], is_slippery=args["is_slippery"],
    render_mode=args["render_mode"])

simulator = FrozenLakeSimulator(env.P)

V_vit, Q_vit = value_iteration(
    simulator, args["gamma"], args["vit_thres"])
# global Q_vit_g = Q_vit
        
for state in range(simulator.num_states):
    logging.warning(f"\n-> state = {state}")
    logging.warning(f"V[state] = {V_vit[state]:0.4f}")
    for action in range(simulator.num_actions):
        logging.warning(f"Q[state][action] = {Q_vit[state][action]:0.4f}")
    logging.warning(f"best_action={np.argmax(Q_vit[state])}")
    
manager = mp.Manager()
ep_reward_list = manager.list()
Q_mcts_list = manager.list()

def run_trial(i_trial, Q_vit, args):

    random.seed(10000+i_trial)
    np.random.seed(10000+i_trial)

    env = FrozenLakeCustom(
        map_name=args["map_name"], is_slippery=args["is_slippery"],
        render_mode=args["render_mode"])

    simulator = FrozenLakeSimulator(env.P)

    Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)

    ep_reward_list.append(ep_reward)
    Q_mcts_list.append(Q_mcts)
    return ep_reward

# %%
args["update_method"] = "max"
args["rollout_method"] = ""
args["action_multi"] = 4
# args["mcts_max_depth"] = 

print(f"num_trials = {args['num_trials']}")
# print(f"mcts_num_trajectories = {args['mcts_num_trajectories']}")

Q_mcts_dict = defaultdict()



hparam_ucb_scale_list = np.arange(10, 100, 10)
# hparam_ucb_scale_list = np.arange(20, 64, 4)
hparam_ucb_scale_list = [1, 2, 4, 8, 16, 32, 64, 128]
# hparam_ucb_scale_list = [2**i for i in range(1, 9)]


num_trajectories_list = [200, 500, 1000, 1500, 2000, 2500, 3000]
# num_trajectories_list = [200, 500, 800]
# num_trajectories_list = [2]
best_param_list = []
max_reward_mean_list = []
res_text1 = ""
res_text2 = ""
for num_trajectories in num_trajectories_list:
    print(f"\n-> num_trajectories = {num_trajectories}")
    args["mcts_num_trajectories"] = num_trajectories
    
    best_param = None
    max_reward_mean = -np.inf
    start_time = time.time()
    res_text1 += f"{num_trajectories} "
    res_text2 += f"{num_trajectories} "
    for hparam_ucb_scale in hparam_ucb_scale_list:
        # start_time = time.time()

        # print(f"hparam_ucb_scale = {hparam_ucb_scale}")
        args["hparam_ucb_scale"] = hparam_ucb_scale
        
        pool = mp.Pool()
        pool.starmap(run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])

        reward_mean = np.mean(ep_reward_list)
        reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
        reward_error = reward_std/np.sqrt(args["num_trials"])
        if hparam_ucb_scale <= 8:
            res_text1 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
        else:
            res_text2 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
        print(f"reward = {reward_mean:0.2f} +/- {reward_error:0.2f}")

        Q_mcts_dict[f"{hparam_ucb_scale}"] = copy.deepcopy(Q_mcts_list)

        if reward_mean > max_reward_mean:
            max_reward_mean = reward_mean 
            best_param = hparam_ucb_scale
    
        ep_reward_list[:] = []
        Q_mcts_list[:] = []
    
        end_time = time.time()
        # print(f"it takes {end_time-start_time:0.4f}")
    
    res_text1 += "\\\\ \n \hline \n"
    res_text2 += "\\\\ \n \hline \n"
    
    # print(f"max_reward_mean = {max_reward_mean:0.2f}")
    print(f"it takes {end_time-start_time:0.4f}")
    
    max_reward_mean_list.append(max_reward_mean)
    best_param_list.append(best_param)
# Out:
# num_trials = 20
#
# -> num_trajectories = 200
# reward = -96.75 +/- 4.78
# reward = -77.60 +/- 9.49
# reward = -50.20 +/- 10.82
# reward = -12.30 +/- 4.71
# reward = -13.10 +/- 4.67
# reward = -13.20 +/- 4.73
# reward = -24.15 +/- 4.26
# reward = -24.05 +/- 4.05
# it takes 26.8241
#
# -> num_trajectories = 500
# reward = -92.90 +/- 6.73
# reward = -73.40 +/- 10.00
# reward = -27.60 +/- 8.64
# reward = -8.00 +/- 0.79
# reward = -11.90 +/- 4.77
# reward = -6.45 +/- 0.86
# reward = -20.00 +/- 0.00
# reward = -20.00 +/- 0.00
# it takes 66.8101
#
# -> num_trajectories = 1000
# reward = -28.40 +/- 8.85
# reward = -17.20 +/- 6.63
# reward = -11.55 +/- 4.74
# Process ForkPoolWorker-24:
# Traceback (most recent call last):
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-179:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-211:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-209:
# Process ForkPoolWorker-49:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-186:
# Process ForkPoolWorker-238:
# Process ForkPoolWorker-223:
# Process ForkPoolWorker-112:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-236:
# Process ForkPoolWorker-198:
# Process ForkPoolWorker-184:
# Process ForkPoolWorker-145:
# Process ForkPoolWorker-125:
# Process ForkPoolWorker-119:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-193:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-202:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-97:
# Process ForkPoolWorker-138:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-94:
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-149:
# Process ForkPoolWorker-201:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-140:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-189:
# Process ForkPoolWorker-180:
# Process ForkPoolWorker-199:
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-190:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-116:
# Process ForkPoolWorker-92:
# Process ForkPoolWorker-212:
# Process ForkPoolWorker-194:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-183:
# Process ForkPoolWorker-74:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-172:
# Process ForkPoolWorker-175:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-204:
# Process ForkPoolWorker-182:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-142:
# KeyboardInterrupt
# Process ForkPoolWorker-216:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-195:
# Process ForkPoolWorker-122:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-188:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-169:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-234:
# Process ForkPoolWorker-197:
# Process ForkPoolWorker-170:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-53:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-222:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-99:
# Process ForkPoolWorker-84:
# Process ForkPoolWorker-210:
# Process ForkPoolWorker-162:
# Process ForkPoolWorker-164:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-159:
# Process ForkPoolWorker-224:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-90:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-213:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-206:
# Process ForkPoolWorker-200:
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-78:
# Traceback (most recent call last):
# Process ForkPoolWorker-72:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-139:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-136:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-160:
# Traceback (most recent call last):
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-86:
# Process ForkPoolWorker-50:
# Traceback (most recent call last):
# Process ForkPoolWorker-185:
# Process ForkPoolWorker-143:
# Traceback (most recent call last):
# Process ForkPoolWorker-80:
# Traceback (most recent call last):
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-81:
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-218:
# Process ForkPoolWorker-191:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-166:
# KeyboardInterrupt
# Process ForkPoolWorker-237:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-228:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-131:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-221:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-227:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-129:
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-126:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-30:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-128:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-33:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# Process ForkPoolWorker-34:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2477063/1409444508.py in <module>
#      40
#      41         pool = mp.Pool()
# ---> 42         pool.starmap(run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])
#      43
#      44         reward_mean = np.mean(ep_reward_list)
#
# ~/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py in starmap(self, func, iterable, chunksize)
#     274         `func` and (a, b) becomes func(a, b).
#     275         '''
# --> 276         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     277
#     278     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
# ...
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/tmp/ipykernel_2477063/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_2477063/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/tmp/ipykernel_2477063/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
#   File "/tmp/ipykernel_2477063/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/tmp/ipykernel_2477063/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 166, in search
#     logging.info(f"N[next_state]= {self.N[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 469, in run_mcts_trial
#     action = mcts.run(state)
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 121, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     action = self.select_action(cur_state, depth, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 165, in search
#     logging.info(f"Q[next_state]= {self.Q[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 166, in search
#     logging.info(f"N[next_state]= {self.N[next_state]}")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 65, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 679, in array2string
#     if options['legacy'] == '1.13':
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 98, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 223, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 98, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)

# %%
print(best_param_list)

# %%
print(res_text1)
print(res_text2)
