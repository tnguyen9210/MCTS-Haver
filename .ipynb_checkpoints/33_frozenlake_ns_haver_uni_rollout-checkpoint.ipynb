# %%
from collections import defaultdict
import random
import numpy as np
np.set_printoptions(precision=2, suppress=True)

import time
import copy 
import multiprocess as mp

import gym
from env import FrozenLakeCustom, FrozenLakeSimulator

from mcts_haver import run_mcts_trial
from value_iteration import value_iteration

from config import parse_args
from utils import MultiProcess

import logging
logger = logging.getLogger()
logger.setLevel(logging.FATAL)

# %%
np.random.seed(0)
random.seed(0)

# params
args = parse_args()

#
env_id = "FrozenLake-v1"
env = FrozenLakeCustom(
    map_name=args["map_name"], is_slippery=args["is_slippery"],
    render_mode=args["render_mode"])

simulator = FrozenLakeSimulator(env.P)

V_vit, Q_vit = value_iteration(
    simulator, args["gamma"], args["vit_thres"])
# global Q_vit_g = Q_vit
        
for state in range(simulator.num_states):
    logging.warning(f"\n-> state = {state}")
    logging.warning(f"V[state] = {V_vit[state]:0.4f}")
    for action in range(simulator.num_actions):
        logging.warning(f"Q[state][action] = {Q_vit[state][action]:0.4f}")
    logging.warning(f"best_action={np.argmax(Q_vit[state])}")
    
manager = mp.Manager()
ep_reward_list = manager.list()
Q_mcts_list = manager.list()

def run_trial(i_trial, Q_vit, args):

    random.seed(10000+i_trial)
    np.random.seed(10000+i_trial)

    env = FrozenLakeCustom(
        map_name=args["map_name"], is_slippery=args["is_slippery"],
        render_mode=args["render_mode"])

    simulator = FrozenLakeSimulator(env.P)

    Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)

    ep_reward_list.append(ep_reward)
    Q_mcts_list.append(Q_mcts)
    return ep_reward

# %%
args["update_method"] = "haver"
args["rollout_method"] = ""

args["mcts_num_trajectories"] = 1500

print(f"num_trials = {args['num_trials']}")
print(f"mcts_num_trajectories = {args['mcts_num_trajectories']}")

Q_mcts_dict = defaultdict()

hparam_ucb_scale_ary = np.arange(28, 68, 4)
hparam_ucb_scale_ary = [1, 2, 4, 8, 16, 32, 64, 128]
# hparam_ucb_scale_ary = [2**i for i in range(1, 8)]\
hparam_ucb_scale_ary = [100]

# hparam_haver_var_ary = np.arange(0.0, 2, 0.5)
# hparam_haver_var_ary = [0.0001]
# hparam_haver_var_ary = [0.1, 0.0001, 0.5, 1.0, 2.0]
# hparam_haver_var_ary = [2, 5, 7, 10, 15, 20, 50, 70]
hparam_haver_var_ary = [1, 2, 4, 8, 16, 32, 64, 100, 128, 256]


best_param = None
max_reward_mean = -np.inf

for hparam_haver_var in hparam_haver_var_ary[::-1]:
    print(f"\n-> hparam_haver_var = {hparam_haver_var**2}")
    args["hparam_haver_var"] = hparam_haver_var**2
    for hparam_ucb_scale in hparam_ucb_scale_ary:
        print(f"hparam_ucb_scale = {hparam_ucb_scale}")
        args["hparam_ucb_scale"] = hparam_ucb_scale
        
        start_time = time.time()
    
        processes = MultiProcess()
        processes.run(
            run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])

        reward_mean = np.mean(ep_reward_list)
        reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
        print(f"reward = {reward_mean:0.2f} +/- {reward_std:0.2f}")

        Q_mcts_dict[f"{hparam_ucb_scale}"] = copy.deepcopy(Q_mcts_list)

        if reward_mean > max_reward_mean:
            max_reward_mean = reward_mean 
            best_param = hparam_ucb_scale

        ep_reward_list[:] = []
        Q_mcts_list[:] = []

        end_time = time.time()
        print(f"it takes {end_time-start_time:0.4f}")
# Out:
# num_trials = 20
# mcts_num_trajectories = 2000
#
# -> hparam_haver_var = 65536
# hparam_ucb_scale = 100
# reward = -4.00 +/- 0.00
# it takes 22.6848
#
# -> hparam_haver_var = 16384
# hparam_ucb_scale = 100
# reward = -101.00 +/- 0.00
# it takes 4.2699
#
# -> hparam_haver_var = 10000
# hparam_ucb_scale = 100
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-28:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 140, in search
#     self.hparam_haver_var, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 144, in search
#     logging.info(f"var[next_state]= {self.var[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 360, in haver21count
#     for a in range(num_actions):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-34:
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 148, in search
#     logging.info(f"Q[cur_state]= {self.Q[cur_state]}")
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-35:
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-29:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 508, in _array2string
#     lst = _formatArray(a, format_function, options['linewidth'],
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 501, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 434, in _get_format_function
#     return formatdict['float']()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 376, in <lambda>
#     data, precision, floatmode, suppress, sign, legacy=legacy),
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 894, in __init__
#     self.fillFormat(data)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/tmp/ipykernel_426647/1569177164.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 120, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 898, in fillFormat
#     finite_vals = data[isfinite(data)]
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 434, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 144, in search
#     logging.info(f"var[next_state]= {self.var[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 79, in search
#     logging.debug(f"cur_state={cur_state}, depth={depth}, terminated={terminated}")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 120, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 140, in search
#     self.hparam_haver_var, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 64, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 63, in run
#     logging.info(f"\n\n-> it={it}")
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 97, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 144, in search
#     logging.info(f"var[next_state]= {self.var[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 391, in haver21count
#     gam_log = (num_actions_visited*total_nvisits/a_nvisits)**4
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 140, in search
#     self.hparam_haver_var, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/logging/__init__.py", line 1990, in info
#     if len(root.handlers) == 0:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 78, in search
#     logging.debug(f"\n-> search")
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 501, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/logging/__init__.py", line 2002, in debug
#     root.debug(msg, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 434, in _get_format_function
#     return formatdict['float']()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 510, in _array2string
#     summary_insert, options['legacy'])
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 501, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 376, in <lambda>
#     data, precision, floatmode, suppress, sign, legacy=legacy),
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 501, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 853, in _formatArray
#     curr_width=line_width)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 368, in haver21count
#     a_gam = np.sqrt(a_var)*np.sqrt(18/a_nvisits*np.log(gam_log))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 894, in __init__
#     self.fillFormat(data)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 434, in _get_format_function
#     return formatdict['float']()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 807, in recurser
#     word = recurser(index + (-i,), next_hanging_indent, next_width)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 905, in fillFormat
#     with errstate(over='ignore'):  # division can overflow
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 375, in <lambda>
#     'float': lambda: FloatingFormat(
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 434, in _get_format_function
#     return formatdict['float']()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 761, in recurser
#     return format_function(a[index])
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 376, in <lambda>
#     data, precision, floatmode, suppress, sign, legacy=legacy),
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 430, in __enter__
#     self.oldstate = seterr(**self.kwargs)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 981, in __call__
#     if not np.isfinite(x):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 894, in __init__
#     self.fillFormat(data)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 110, in seterr
#     old = geterr()
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 905, in fillFormat
#     with errstate(over='ignore'):  # division can overflow
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 174, in geterr
#     val = (maskvalue >> SHIFT_UNDERFLOW) & mask
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/_ufunc_config.py", line 426, in __init__
#     self.call = call
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_426647/1156322970.py in <module>
#      35         processes = MultiProcess()
#      36         processes.run(
# ---> 37             run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])
#      38
#      39         reward_mean = np.mean(ep_reward_list)
#
# /data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/utils.py in run(self, func, args_list)
#      31
#      32         self.pool.close()
# ---> 33         self.pool.join()
#      34         return
#
# ~/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py in join(self)
#     554         elif self._state not in (CLOSE, TERMINATE):
#     555             raise ValueError("In unknown state")
# --> 556         self._worker_handler.join()
#     557         self._task_handler.join()
#     558         self._result_handler.join()
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
Q_mcts_avg = defaultdict(lambda: np.zeros(simulator.num_actions))
for i_trial, Q_mcts in enumerate(Q_mcts_dict[f"{best_param}"]):
    for s in range(16):
        Q_mcts_avg[s] = (1-1/(i_trial+1))*Q_mcts_avg[s] + 1/(i_trial+1)*Q_mcts[s]

Q_mcts_avg = Q_mcts_dict[f"{best_param}"][1]
for state in range(simulator.num_states):
    print(f"\n-> state = {state}")
    print(f"V[state] = {np.max(Q_mcts_avg[state]):0.4f} | {np.max(Q_vit[state]):0.4f}")
    for action in range(simulator.num_actions):
        print(f"Q[state][action] = {Q_mcts_avg[state][action]:0.4f} | {Q_vit[state][action]:0.4f}")
    print(f"best_action = {np.argmax(Q_mcts_avg[state])} | {np.argmax(Q_vit[state])}")
