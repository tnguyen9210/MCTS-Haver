# %%
from collections import defaultdict
import random
import numpy as np
np.set_printoptions(precision=2, suppress=True)

import time
import copy 
import multiprocess as mp

import gym
from env import FrozenLakeCustom, FrozenLakeSimulator

from mcts_haver import run_mcts_trial
from value_iteration import value_iteration

from config import parse_args
from utils import MultiProcess

import logging
logger = logging.getLogger()
logger.setLevel(logging.FATAL)

# %%
np.random.seed(0)
random.seed(0)


# params
args = parse_args()

m = args["num_trials"]
random_seeds = np.loadtxt("random_seeds.txt").astype("int64")
env_seeds = random_seeds[:m]
simulator_seeds = random_seeds[m:2*m]
mcts_seeds = random_seeds[2*m:]

#
env_id = "FrozenLake-v1"
env = FrozenLakeCustom(
    map_name=args["map_name"], is_slippery=args["is_slippery"],
    render_mode=args["render_mode"])

simulator = FrozenLakeSimulator(env.P, simulator_seed=0)

V_vit, Q_vit = value_iteration(
    simulator, args["gamma"], args["vit_thres"])
# global Q_vit_g = Q_vit
        
for state in range(simulator.num_states):
    logging.warning(f"\n-> state = {state}")
    logging.warning(f"V[state] = {V_vit[state]:0.4f}")
    for action in range(simulator.num_actions):
        logging.warning(f"Q[state][action] = {Q_vit[state][action]:0.4f}")
    logging.warning(f"best_action={np.argmax(Q_vit[state])}")
    
        
manager = mp.Manager()
ep_reward_list = manager.list()
Q_mcts_list = manager.list()

def run_trial(i_trial, Q_vit, env_seed, simulator_seed, mcts_seed, args):

    # random.seed(random_seeds[i_trial])
    # np.random.seed(random_seeds[i_trial])

    env = FrozenLakeCustom(
        map_name=args["map_name"], is_slippery=args["is_slippery"],
        render_mode=args["render_mode"])

    simulator = FrozenLakeSimulator(env.P, simulator_seed)

    Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)

    ep_reward_list.append(ep_reward)
    Q_mcts_list.append(Q_mcts)
    return ep_reward

# %%
args["update_method"] = "haver"
args["rollout_method"] = ""

print(f"num_trials = {args['num_trials']}")
# print(f"mcts_num_trajectories = {args['mcts_num_trajectories']}")


hparam_ucb_scale_list = np.arange(10, 100, 10)
hparam_ucb_scale_list = [32, 64, 128, 256, 512, 1024]
# hparam_ucb_scale_list = [2**i for i in range(1, 9)]
args["hparam_ucb_scale"] = 64

hparam_haver_std_list = np.arange(10, 100, 10)
hparam_haver_std_list = [1/16, 1/8, 1/4, 1, 4, 8, 16]
# hparam_haver_std_list = [2**i for i in range(1, 9)]


# num_trajectories_list = [200, 500, 1000, 1500, 2000, 2500, 3000]
num_trajectories_list = [200]
# num_trajectories_list = [2]
best_param_list = []
max_reward_mean_list = []
res_text1 = ""
res_text2 = ""
for num_trajectories in num_trajectories_list:
    print(f"\n-> num_trajectories = {num_trajectories}")
    args["mcts_num_trajectories"] = num_trajectories
    
    # best_param = None
    # max_reward_mean = -np.inf
    start_time = time.time()
    res_text1 += f"{num_trajectories} "
    res_text2 += f"{num_trajectories} "
    for hparam_ucb_scale in hparam_ucb_scale_list: 
        
        args["hparam_ucb_scale"] = hparam_ucb_scale
        print(f"\n-> hparam_ucb_scale = {hparam_ucb_scale}")
        
        max_reward_mean = -np.inf
        best_param = None
        max_reward_error = None
        
        for hparam_haver_std in hparam_haver_std_list:
            # start_time = time.time()

            args["hparam_haver_var"] = hparam_haver_std**2
            # print(f"hparam_haver_var = {args['hparam_haver_var']}")
            # print(f"hparam_ucb_scale = {args['hparam_ucb_scale']}")

            pool = mp.Pool()
            pool.starmap(
                run_trial, 
                [(i, Q_vit, env_seeds[i], simulator_seeds[i], mcts_seeds[i], args) for i in range(args["num_trials"])])

            reward_mean = np.mean(ep_reward_list)
            reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
            reward_error = reward_std/np.sqrt(args["num_trials"])
            # if hparam_haver_std <= 8:
            #     res_text1 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
            # else:
            #     res_text2 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
            print(f"reward = {reward_mean:0.2f} \u00B1 {reward_error:0.2f}")

            if reward_mean > max_reward_mean:
                max_reward_mean = reward_mean 
                max_reward_error = reward_error
                best_param = hparam_haver_std
                
            ep_reward_list[:] = []
            Q_mcts_list[:] = []

            end_time = time.time()
            # print(f"it takes {end_time-start_time:0.4f}")
        
        if hparam_ucb_scale <= 128:
            res_text1 += f"& {max_reward_mean:0.2f} (\u00B1{max_reward_error:0.2f}) "
        else:
            res_text2 += f"& {max_reward_mean:0.2f} (\u00B1{max_reward_error:0.2f}) "
            
        print(f"max_reward = {max_reward_mean:0.2f} \u00B1 {max_reward_error:0.2f}")
        print(f"best_param = {best_param}")
            
    res_text1 += "\\\\ \n \hline \n"
    res_text2 += "\\\\ \n \hline \n"

    # print(f"max_reward_mean = {max_reward_mean:0.2f}")
    print(f"it takes {end_time-start_time:0.4f}")

    max_reward_mean_list.append(max_reward_mean)
    best_param_list.append(best_param)
# Out:
# num_trials = 500
#
# -> num_trajectories = 200
#
# -> hparam_ucb_scale = 10
# reward = -62.08 ± 2.12
# reward = -61.52 ± 2.13
# reward = -61.09 ± 2.13
# reward = -59.94 ± 2.14
# reward = -59.80 ± 2.14
# reward = -61.54 ± 2.13
# reward = -65.93 ± 2.08
# max_reward = -59.80 ± 2.14
# best_param = 4
#
# -> hparam_ucb_scale = 20
# reward = -37.01 ± 2.05
# reward = -39.95 ± 2.09
# reward = -36.24 ± 2.04
# reward = -42.22 ± 2.12
# reward = -44.80 ± 2.14
# reward = -40.96 ± 2.10
# reward = -45.94 ± 2.15
# max_reward = -36.24 ± 2.04
# best_param = 0.25
#
# -> hparam_ucb_scale = 30
# reward = -30.80 ± 1.93
# reward = -28.04 ± 1.87
# reward = -29.02 ± 1.89
# reward = -31.19 ± 1.94
# reward = -31.15 ± 1.94
# reward = -34.47 ± 2.01
# reward = -37.50 ± 2.06
# max_reward = -28.04 ± 1.87
# best_param = 0.125
#
# -> hparam_ucb_scale = 40
# reward = -30.12 ± 1.92
# reward = -27.20 ± 1.85
# reward = -31.64 ± 1.96
# reward = -27.20 ± 1.85
# reward = -30.51 ± 1.93
# reward = -28.54 ± 1.89
# reward = -35.18 ± 2.02
# max_reward = -27.20 ± 1.85
# best_param = 0.125
#
# -> hparam_ucb_scale = 50
# Process ForkPoolWorker-290:
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-288:
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-289:
# Process ForkPoolWorker-283:
# Process ForkPoolWorker-291:
# Process ForkPoolWorker-282:
# Process ForkPoolWorker-286:
# Process ForkPoolWorker-284:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/var/folders/v6/ml83l13d1358nv1g796w5j240000gn/T/ipykernel_34705/3979847484.py", line 49, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, env_seed, mcts_seed, args)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 154, in search
#     logging.info(f"Q[cur_state][action]= {self.Q[cur_state][action]:0.4f}")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 153, in search
#     logging.info(f"Q[cur_state]= {self.Q[cur_state]}")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 147, in search
#     logging.info(f"Q[next_state]= {self.Q[next_state]}")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 149, in search
#     logging.info(f"var[next_state]= {self.var[next_state]}")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 367, in run_mcts_trial
#     action = mcts.run(state)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/logging/__init__.py", line 2130, in info
#     def info(msg, *args, **kwargs):
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 142, in search
#     self.R[cur_state][action] + haver21count(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 1612, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 1612, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 1612, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
# KeyboardInterrupt
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 68, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 736, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 320, in haver21count
#     num_actions_visited = np.sum(action_nvisits > 0)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 736, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 95, in search
#     action = self.select_action(cur_state, depth, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 736, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 513, in wrapper
#     return f(self, *args, **kwargs)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 95, in search
#     action = self.select_action(cur_state, depth, debug)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 125, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 246, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2313, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 513, in wrapper
#     return f(self, *args, **kwargs)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 513, in wrapper
#     return f(self, *args, **kwargs)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 246, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 546, in _array2string
#     lst = _formatArray(a, format_function, options['linewidth'],
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 1612, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 266, in get_action_max_ucb
#     action_bonuses = np.sqrt(2*np.log(total_nvisits)/my_action_nvisits)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 539, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 258, in get_action_max_ucb
#     n_action_visited = np.sum(action_nvisits > 0)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 539, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 889, in _formatArray
#     return recurser(index=(),
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 736, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 472, in _get_format_function
#     return formatdict['float']()
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2313, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 845, in recurser
#     word = recurser(index + (-i,), next_hanging_indent, next_width)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 458, in _get_format_function
#     formatdict = _get_formatdict(data, **options)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 513, in wrapper
#     return f(self, *args, **kwargs)
#   [Previous line repeated 1 more time]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 411, in <lambda>
#     'float': lambda: FloatingFormat(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 403, in _get_formatdict
#     def _get_formatdict(data, *, precision, floatmode, suppress, sign, legacy,
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 799, in recurser
#     return format_function(a[index])
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 539, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 91, in search
#     return self.rollout(cur_state)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 907, in __init__
#     def __init__(self, data, precision, floatmode, suppress_small, sign=False,
# KeyboardInterrupt
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 1019, in __call__
#     if not np.isfinite(x):
# KeyboardInterrupt
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 472, in _get_format_function
#     return formatdict['float']()
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 298, in rollout
#     action = self.rng.choice(range(self.num_actions))
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 102, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 411, in <lambda>
#     'float': lambda: FloatingFormat(
# KeyboardInterrupt
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 932, in __init__
#     self.fillFormat(data)
#   [Previous line repeated 1 more time]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/arrayprint.py", line 942, in fillFormat
#     min_val = np.min(abs_non_zero)
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 91, in search
#     return self.rollout(cur_state)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2953, in min
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#   File "/Users/tnn/Documents/GitHub/MCTS-Haver/mcts_haver.py", line 298, in rollout
#     action = self.rng.choice(range(self.num_actions))
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 51
#      47 # print(f"hparam_haver_var = {args['hparam_haver_var']}")
#      48 # print(f"hparam_ucb_scale = {args['hparam_ucb_scale']}")
#      50 pool = mp.Pool()
# ---> 51 pool.starmap(
#      52     run_trial,
#      53     [(i, Q_vit, env_seeds[i], simulator_seeds[i], mcts_seeds[i], args) for i in range(args["num_trials"])])
#      55 reward_mean = np.mean(ep_reward_list)
#      56 reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tnn1/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
print(res_text1)
print(res_text2)
# Out:
# 200 \\
#  \hline
#
# 200 & -29.23 (±1.90) & -24.89 (±1.78) & -24.37 (±1.76) & -26.28 (±1.82) & -21.49 (±1.66) \\
#  \hline

# %%
args["update_method"] = "haver"
args["rollout_method"] = ""

print(f"num_trials = {args['num_trials']}")
# print(f"mcts_num_trajectories = {args['mcts_num_trajectories']}")


hparam_ucb_scale_list = np.arange(10, 100, 10)
hparam_ucb_scale_list = [32, 64, 128, 256, 512, 1024]
# hparam_ucb_scale_list = [2**i for i in range(1, 9)]
args["hparam_ucb_scale"] = 64

hparam_haver_std_list = np.arange(10, 100, 10)
hparam_haver_std_list = [1/16, 1/8, 1/4, 1, 4, 8, 16]
# hparam_haver_std_list = [2**i for i in range(1, 9)]


# num_trajectories_list = [200, 500, 1000, 1500, 2000, 2500, 3000]
num_trajectories_list = [500]
# num_trajectories_list = [2]
best_param_list = []
max_reward_mean_list = []
res_text1 = ""
res_text2 = ""
for num_trajectories in num_trajectories_list:
    print(f"\n-> num_trajectories = {num_trajectories}")
    args["mcts_num_trajectories"] = num_trajectories
    
    # best_param = None
    # max_reward_mean = -np.inf
    start_time = time.time()
    res_text1 += f"{num_trajectories} "
    res_text2 += f"{num_trajectories} "
    for hparam_ucb_scale in hparam_ucb_scale_list: 
        
        args["hparam_ucb_scale"] = hparam_ucb_scale
        print(f"\n-> hparam_ucb_scale = {hparam_ucb_scale}")
        
        max_reward_mean = -np.inf
        best_param = None
        max_reward_error = None
        
        for hparam_haver_std in hparam_haver_std_list:
            # start_time = time.time()

            args["hparam_haver_var"] = hparam_haver_std**2
            # print(f"hparam_haver_var = {args['hparam_haver_var']}")
            # print(f"hparam_ucb_scale = {args['hparam_ucb_scale']}")

            pool = mp.Pool()
            pool.starmap(
                run_trial, 
                [(i, Q_vit, env_seeds[i], simulator_seeds[i], mcts_seeds[i], args) for i in range(args["num_trials"])])

            reward_mean = np.mean(ep_reward_list)
            reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
            reward_error = reward_std/np.sqrt(args["num_trials"])
            # if hparam_haver_std <= 8:
            #     res_text1 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
            # else:
            #     res_text2 += f"& {reward_mean:0.2f} (\u00B1{reward_error:0.2f}) "
            print(f"reward = {reward_mean:0.2f} \u00B1 {reward_error:0.2f}")

            if reward_mean > max_reward_mean:
                max_reward_mean = reward_mean 
                max_reward_error = reward_error
                best_param = hparam_haver_std
                
            ep_reward_list[:] = []
            Q_mcts_list[:] = []

            end_time = time.time()
            # print(f"it takes {end_time-start_time:0.4f}")
        
        if hparam_ucb_scale <= 128:
            res_text1 += f"& {max_reward_mean:0.2f} (\u00B1{max_reward_error:0.2f}) "
        else:
            res_text2 += f"& {max_reward_mean:0.2f} (\u00B1{max_reward_error:0.2f}) "
            
        print(f"max_reward = {max_reward_mean:0.2f} \u00B1 {max_reward_error:0.2f}")
        print(f"best_param = {best_param}")
            
    res_text1 += "\\\\ \n \hline \n"
    res_text2 += "\\\\ \n \hline \n"

    # print(f"max_reward_mean = {max_reward_mean:0.2f}")
    print(f"it takes {end_time-start_time:0.4f}")

    max_reward_mean_list.append(max_reward_mean)
    best_param_list.append(best_param)
# Out:
# num_trials = 500
#
# -> num_trajectories = 500
#
# -> hparam_ucb_scale = 32
# reward = -19.00 ± 1.57
# reward = -20.75 ± 1.64
# reward = -18.44 ± 1.54
# reward = -20.74 ± 1.64
# reward = -21.36 ± 1.66
# reward = -17.84 ± 1.51
# reward = -23.30 ± 1.73
# max_reward = -17.84 ± 1.51
# best_param = 8
#
# -> hparam_ucb_scale = 64
# reward = -20.69 ± 1.64
# reward = -19.14 ± 1.58
# reward = -17.20 ± 1.49
# reward = -18.76 ± 1.56
# reward = -18.75 ± 1.56
# reward = -19.92 ± 1.61
# reward = -20.70 ± 1.64
# max_reward = -17.20 ± 1.49
# best_param = 0.25
#
# -> hparam_ucb_scale = 128
# reward = -13.14 ± 1.27
# reward = -15.65 ± 1.41
# reward = -17.00 ± 1.48
# reward = -17.59 ± 1.51
# reward = -17.98 ± 1.52
# reward = -18.17 ± 1.53
# reward = -21.09 ± 1.65
# max_reward = -13.14 ± 1.27
# best_param = 0.0625
#
# -> hparam_ucb_scale = 256
# reward = -21.29 ± 1.66
# reward = -20.70 ± 1.64
# reward = -23.60 ± 1.74
# reward = -22.25 ± 1.70
# reward = -22.05 ± 1.69
# reward = -24.58 ± 1.78
# reward = -28.07 ± 1.87
# max_reward = -20.70 ± 1.64
# best_param = 0.125
#
# -> hparam_ucb_scale = 512
# reward = -18.36 ± 1.54
# reward = -18.17 ± 1.53
# reward = -17.58 ± 1.51
# reward = -19.74 ± 1.60
# reward = -19.33 ± 1.58
# reward = -21.48 ± 1.67
# reward = -20.90 ± 1.65
# max_reward = -17.58 ± 1.51
# best_param = 0.25
#
# -> hparam_ucb_scale = 1024
# reward = -14.10 ± 1.33
# reward = -15.27 ± 1.39
# reward = -15.27 ± 1.39
# reward = -17.98 ± 1.52
# reward = -19.54 ± 1.59
# reward = -21.08 ± 1.65
# reward = -20.89 ± 1.65
# max_reward = -14.10 ± 1.33
# best_param = 0.0625
# it takes 4886.3269

# %%
print(res_text1)
print(res_text2)
# Out:
# 500 & -17.84 (±1.51) & -17.20 (±1.49) & -13.14 (±1.27) \\
#  \hline
#
# 500 & -20.70 (±1.64) & -17.58 (±1.51) & -14.10 (±1.33) \\
#  \hline
