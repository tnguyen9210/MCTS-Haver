# %%
from collections import defaultdict
import random
import numpy as np
np.set_printoptions(precision=2, suppress=True)

import time
import copy 
import multiprocess as mp

import gym
from env import FrozenLakeCustom, FrozenLakeSimulator

from mcts_haver import run_mcts_trial
from value_iteration import value_iteration

from config import parse_args
from utils import MultiProcess

import logging
logger = logging.getLogger()
logger.setLevel(logging.FATAL)

# %%
np.random.seed(0)
random.seed(0)

# params
args = parse_args()

#
env_id = "FrozenLake-v1"
env = FrozenLakeCustom(
    map_name=args["map_name"], is_slippery=args["is_slippery"],
    render_mode=args["render_mode"])

simulator = FrozenLakeSimulator(env.P)

V_vit, Q_vit = value_iteration(
    simulator, args["gamma"], args["vit_thres"])
# global Q_vit_g = Q_vit
        
for state in range(simulator.num_states):
    logging.warning(f"\n-> state = {state}")
    logging.warning(f"V[state] = {V_vit[state]:0.4f}")
    for action in range(simulator.num_actions):
        logging.warning(f"Q[state][action] = {Q_vit[state][action]:0.4f}")
    logging.warning(f"best_action={np.argmax(Q_vit[state])}")
    
manager = mp.Manager()
ep_reward_list = manager.list()
Q_mcts_list = manager.list()

def run_trial(i_trial, Q_vit, args):

    random.seed(10000+i_trial)
    np.random.seed(10000+i_trial)

#     env = FrozenLakeCustom(
#         map_name=args["map_name"], is_slippery=args["is_slippery"],
#         render_mode=args["render_mode"])

#     simulator = FrozenLakeSimulator(env.P)

    Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)

    ep_reward_list.append(ep_reward)
    Q_mcts_list.append(Q_mcts)
    return ep_reward

# %%
args["update_method"] = "avg"
args["rollout_method"] = ""

print(f"num_trials = {args['num_trials']}")
# print(f"mcts_num_trajectories = {args['mcts_num_trajectories']}")

Q_mcts_dict = defaultdict()



hparam_ucb_scale_list = np.arange(10, 100, 10)
# hparam_ucb_scale_list = np.arange(20, 64, 4)
hparam_ucb_scale_list = [1, 2, 4, 8, 16, 32, 64, 128]
# hparam_ucb_scale_list = [2**i for i in range(1, 9)]


num_trajectories_list = [200, 500, 1000, 1500, 2000, 2500, 3000]
# num_trajectories_list = [200, 500, 800]
# num_trajectories_list = [800]
best_param_list = []
max_reward_mean_list = []
for num_trajectories in num_trajectories_list:
    print(f"\n-> num_trajectories = {num_trajectories}")
    args["mcts_num_trajectories"] = num_trajectories
    
    best_param = None
    max_reward_mean = -np.inf
    start_time = time.time()
    for hparam_ucb_scale in hparam_ucb_scale_list:
        # start_time = time.time()

        # print(f"hparam_ucb_scale = {hparam_ucb_scale}")
        args["hparam_ucb_scale"] = hparam_ucb_scale
        
        processes = MultiProcess()
        processes.run(
            run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])

        reward_mean = np.mean(ep_reward_list)
        # reward_std = np.std(ep_reward_list, ddof=1) if len(ep_reward_list) > 1 else 0
        # print(f"reward = {reward_mean:0.2f} +/- {reward_std:0.2f}")

        Q_mcts_dict[f"{hparam_ucb_scale}"] = copy.deepcopy(Q_mcts_list)

        if reward_mean > max_reward_mean:
            max_reward_mean = reward_mean 
            best_param = hparam_ucb_scale
    
        ep_reward_list[:] = []
        Q_mcts_list[:] = []
    
        end_time = time.time()
        # print(f"it takes {end_time-start_time:0.4f}")
        
    print(f"max_reward_mean = {max_reward_mean:0.2f}")
    print(f"it takes {end_time-start_time:0.4f}")
    
    max_reward_mean_list.append(max_reward_mean)
    best_param_list.append(best_param)
# Out:
# num_trials = 20
#
# -> num_trajectories = 200
# hparam_ucb_scale = 1
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 2
# reward = -101.15 +/- 0.55
# hparam_ucb_scale = 4
# reward = -101.08 +/- 0.28
# hparam_ucb_scale = 8
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 16
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 32
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 64
# reward = -101.10 +/- 0.32
# hparam_ucb_scale = 128
# reward = -101.00 +/- 0.00
# max_reward_mean = -101.00
# it takes 2.3254
#
# -> num_trajectories = 500
# hparam_ucb_scale = 1
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 2
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 4
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 8
# reward = -101.00 +/- 0.00
# hparam_ucb_scale = 16
# Process ForkPoolWorker-154:
# Process ForkPoolWorker-147:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-149:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-152:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-151:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-150:
# Process ForkPoolWorker-156:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 321, in issubclass_
#     return issubclass(arg1, arg2)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: issubclass() arg 1 must be a class
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 89, in search
#     self.simulator.step(cur_state, action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 111, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/env.py", line 134, in step
#     transitions = self.trans_probs[int(state)][action]
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 89, in search
#     self.simulator.step(cur_state, action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 119, in search
#     elif np.sum(self.N[next_state]) > 0:
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 84, in search
#     action = self.select_action(cur_state, depth, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 111, in search
#     logging.info(f"\n-> depth-0, cur_state={cur_state}, action={action}, {self.N[next_state]}")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 84, in search
#     action = self.select_action(cur_state, depth, debug)
# KeyboardInterrupt
#   File "/tmp/ipykernel_206565/1191084713.py", line 41, in run_trial
#     Q_mcts, ep_reward = run_mcts_trial(env, simulator, Q_vit, i_trial, args)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 89, in search
#     self.simulator.step(cur_state, action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 89, in search
#     self.simulator.step(cur_state, action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/env.py", line 137, in step
#     idx = np.random.choice(len(trans_p), 1, p=trans_p)[0]
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "<__array_function__ internals>", line 6, in sum
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 1551, in _array_str_implementation
#     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 226, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 440, in run_mcts_trial
#     action = mcts.run(state)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/env.py", line 137, in step
#     idx = np.random.choice(len(trans_p), 1, p=trans_p)[0]
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 84, in search
#     action = self.select_action(cur_state, depth, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/env.py", line 137, in step
#     idx = np.random.choice(len(trans_p), 1, p=trans_p)[0]
#   File "mtrand.pyx", line 923, in numpy.random.mtrand.RandomState.choice
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 698, in array2string
#     return _array2string(a, options, separator, prefix)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 260, in get_action_max_ucb
#     if np.sum(action_nvisits > 0) < self.num_actions:
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2260, in sum
#     initial=initial, where=where)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 58, in run
#     self.search(cur_state, 0, False, debug=False)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 226, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 84, in search
#     action = self.select_action(cur_state, depth, debug)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 475, in wrapper
#     return f(self, *args, **kwargs)
#   File "mtrand.pyx", line 946, in numpy.random.mtrand.RandomState.choice
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/getlimits.py", line 389, in __new__
#     obj = cls._finfo_cache.get(dtype, None)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 226, in select_action
#     action = self.get_action_max_ucb(action_values, action_nvisits, debug)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 70, in _wrapreduction
#     passkwargs = {k: v for k, v in kwargs.items()
#   File "<__array_function__ internals>", line 6, in prod
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 501, in _array2string
#     format_function = _get_format_function(data, **options)
#   File "<__array_function__ internals>", line 6, in sum
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 266, in get_action_max_ucb
#     action_bonuses = np.sqrt(2*np.log(total_nvisits)/action_nvisits)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 510, in _array2string
#     summary_insert, options['legacy'])
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2260, in sum
#     initial=initial, where=where)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 3052, in prod
#     keepdims=keepdims, initial=initial, where=where)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 265, in get_action_max_ucb
#     total_nvisits = np.sum(action_nvisits)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 422, in _get_format_function
#     formatdict = _get_formatdict(data, **options)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 853, in _formatArray
#     curr_width=line_width)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 91, in search
#     q = reward + self.gamma*self.search(next_state, depth+1, terminated, debug)
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "<__array_function__ internals>", line 6, in sum
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 758, in recurser
#     axes_left = a.ndim - axis
#   [Previous line repeated 1 more time]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/arrayprint.py", line 367, in _get_formatdict
#     def _get_formatdict(data, *, precision, floatmode, suppress, sign, legacy,
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2259, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 80, in search
#     return self.rollout(cur_state)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/mcts_haver.py", line 310, in rollout
#     self.simulator.step(cur_state, action)
#   File "/data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/env.py", line 137, in step
#     idx = np.random.choice(len(trans_p), 1, p=trans_p)[0]
#   File "mtrand.pyx", line 922, in numpy.random.mtrand.RandomState.choice
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 417, in issubdtype
#     if not issubclass_(arg1, generic):
#   File "/home/tnn/miniconda3/envs/tnn1/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 321, in issubclass_
#     return issubclass(arg1, arg2)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_206565/4178778268.py in <module>
#      35         processes = MultiProcess()
#      36         processes.run(
# ---> 37             run_trial, [(i, Q_vit, args) for i in range(args["num_trials"])])
#      38
#      39         reward_mean = np.mean(ep_reward_list)
#
# /data/tnn/10_School/02_ResearchProjects/01_MaxEstimator/01_main_codes/31_mcts_v11/MCTS-Haver/utils.py in run(self, func, args_list)
#      31
#      32         self.pool.close()
# ---> 33         self.pool.join()
#      34         return
#
# ~/miniconda3/envs/tnn1/lib/python3.7/site-packages/multiprocess/pool.py in join(self)
#     554         elif self._state not in (CLOSE, TERMINATE):
#     555             raise ValueError("In unknown state")
# --> 556         self._worker_handler.join()
#     557         self._task_handler.join()
#     558         self._result_handler.join()
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/miniconda3/envs/tnn1/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
print(best_param_list)
